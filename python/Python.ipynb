# %%
l=[9,0,67,0,8,8]
# how to remove the duplicate element
set(l)
# Out:
# {0, 8, 9, 67}

# %%
s={89,90,6,'p',78888888,4556,9,(8,88)}
s
# Out:
# {(8, 88), 4556, 6, 78888888, 89, 9, 90, 'p'}

# %%
s={9,9,0}
s.add(7)
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}
s.update([7,8,9,])
s
# Out:
# {0, 7, 8, 9}

# %%
s={9,9,0}
s.add((8,9,0))
s
# Out:
# {(8, 9, 0), 0, 9}

# %%
# i want to delete value 
s={5,8,9,}
s.remove(9)
s
# Out:
# {5, 8}

# %%
s={5,8,9,}
s.discard(9)
s
# Out:
# {5, 8}

# %%
s={9,80,60}
s.pop()
s
# Out:
# {9, 60}

# %%
l=[7,9,80,98]
l.pop()
# Out:
# 98
