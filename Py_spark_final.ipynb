# %% [markdown]
# <a href="https://colab.research.google.com/github/kantesholekar45-arch/Github_experiment/blob/master/Py_spark_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('pyspark fundamentals').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://a46343383f08:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark fundamentals</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = [
    ("Zaid",66,15,"India"),
    ("shivaraj",78,15,"India"),
    ("John",66,50,"UK"),
    ("sara",97,89,"USA")
    ]
columns =["name","age","experience","country"]

# %%
df = spark.createDataFrame(data,columns)

# %%
df.show()
# Out:
# +--------+---+----------+-------+
# |    name|age|experience|country|
# +--------+---+----------+-------+
# |    Zaid| 66|        15|  India|
# |shivaraj| 78|        15|  India|
# |    John| 66|        50|     UK|
# |    sara| 97|        89|    USA|
# +--------+---+----------+-------+

# %%
df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- experience: long (nullable = true)
#  |-- country: string (nullable = true)

# %%
df.select("name","age").show()
# Out:
# +--------+---+
# |    name|age|
# +--------+---+
# |    Zaid| 66|
# |shivaraj| 78|
# |    John| 66|
# |    sara| 97|
# +--------+---+

# %%
df.filter(df.age>66).show()
# Out:
# +--------+---+----------+-------+
# |    name|age|experience|country|
# +--------+---+----------+-------+
# |shivaraj| 78|        15|  India|
# |    sara| 97|        89|    USA|
# +--------+---+----------+-------+
#
# +--------+---+----------+-------+
# |    name|age|experience|country|
# +--------+---+----------+-------+
# |shivaraj| 78|        15|  India|
# |    sara| 97|        89|    USA|
# +--------+---+----------+-------+

# %%
df.groupBy("country",).count().show()
# Out:
# +-------+-----+
# |country|count|
# +-------+-----+
# |  India|    2|
# |    USA|    1|
# |     UK|    1|
# +-------+-----+

# %%
df.show()
# Out:
# +--------+---+----------+-------+
# |    name|age|experience|country|
# +--------+---+----------+-------+
# |    Zaid| 66|        15|  India|
# |shivaraj| 78|        15|  India|
# |    John| 66|        50|     UK|
# |    sara| 97|        89|    USA|
# +--------+---+----------+-------+

# %%
df.count()
# Out:
# 4

# %%
ls
# Out:
# sample_data/  spotify_analysis_dataset.csv

# %%
df=spark.read.csv("/content/spotify_analysis_dataset.csv",
                  header=True,
                  inferSchema=True)

# %%
df.show()
# Out:
# +--------+----------+---------+--------+------------+-----------+----------+------------+------+--------+-----------+------------+----------------+--------+-------+------+
# |track_id|track_name|   artist|   album|release_date|duration_ms|popularity|danceability|energy|loudness|speechiness|acousticness|instrumentalness|liveness|valence| tempo|
# +--------+----------+---------+--------+------------+-----------+----------+------------+------+--------+-----------+------------+----------------+--------+-------+------+
# | TRK1000|    Song 0| Artist 7| Album 3|  2010-01-01|     240151|        70|       0.037| 0.349|   -2.87|      0.522|       0.616|           0.931|   0.947|  0.353|110.14|
# | TRK1001|    Song 1| Artist 4| Album 5|  2010-01-02|     253767|        58|        0.61| 0.726|  -22.87|       0.77|       0.635|           0.858|   0.986|  0.584|  75.9|
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- track_id: string (nullable = true)
#  |-- track_name: string (nullable = true)
#  |-- artist: string (nullable = true)
#  |-- album: string (nullable = true)
#  |-- release_date: date (nullable = true)
#  |-- duration_ms: integer (nullable = true)
#  |-- popularity: integer (nullable = true)
#  |-- danceability: double (nullable = true)
#  |-- energy: double (nullable = true)
#  |-- loudness: double (nullable = true)
#  |-- speechiness: double (nullable = true)
#  |-- acousticness: double (nullable = true)
#  |-- instrumentalness: double (nullable = true)
#  |-- liveness: double (nullable = true)
#  |-- valence: double (nullable = true)
#  |-- tempo: double (nullable = true)

# %%
df.count()
# Out:
# 50

# %%
df.select("Track_name").show()
# Out:
# +----------+
# |Track_name|
# +----------+
# |    Song 0|
# |    Song 1|
# |    Song 2|
# |    Song 3|
# |    Song 4|
# |    Song 5|
# |    Song 6|
# |    Song 7|
# |    Song 8|
# |    Song 9|
# |   Song 10|
# |   Song 11|
# |   Song 12|
# |   Song 13|
# |   Song 14|
# |   Song 15|
# |   Song 16|
# |   Song 17|
# |   Song 18|
# |   Song 19|
# +----------+
# only showing top 20 rows

# %%
df.filter(df.popularity > 50).select("popularity").show()
# Out:
# +----------+
# |popularity|
# +----------+
# |        70|
# |        58|
# |        85|
# |        65|
# |        61|
# |        56|
# |        83|
# |        61|
# |        74|
# |        91|
# |        88|
# |        61|
# |        96|
# |        61|
# |        76|
# |        69|
# |        71|
# |        61|
# |        96|
# |        78|
# +----------+
# only showing top 20 rows

# %%
df.select("popularity").describe().show()
# Out:
# +-------+------------------+
# |summary|        popularity|
# +-------+------------------+
# |  count|                50|
# |   mean|             50.32|
# | stddev|27.528419452468036|
# |    min|                 0|
# |    max|                96|
# +-------+------------------+

# %%
df.groupBy("artist").count().show()
# Out:
# +---------+-----+
# |   artist|count|
# +---------+-----+
# | Artist 2|    2|
# | Artist 8|    5|
# | Artist 9|    2|
# |Artist 12|    7|
# | Artist 7|    4|
# | Artist 5|    4|
# | Artist 3|    3|
# |Artist 14|    4|
# | Artist 1|    2|
# | Artist 6|    3|
# |Artist 13|    3|
# |Artist 10|    3|
# | Artist 4|    3|
# |Artist 11|    5|
# +---------+-----+
