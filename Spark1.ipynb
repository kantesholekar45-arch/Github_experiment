# %% [markdown]
# <a href="https://colab.research.google.com/github/kantesholekar45-arch/Github_experiment/blob/master/Spark1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark
import pandas as pd

# %%
df=pd.read_csv('/content/test1.csv')
df.head() #by default its givig first 5 data
# Out:
#        Name  age  Experience  Salary
# 0       Ben   31          10   30000
# 1  Srikanth   30           8   25000
# 2     Sunny   29           4   20000
# 3      Paul   24           3   20000
# 4    Harish   21           1   15000

# %%
type(pd.read_csv('/content/test1.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Demo').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://e6631302f8ba:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Demo</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df=spark.read.csv('/content/test1.csv')
df.show()
# Out:
# +--------+---+----------+------+
# |     _c0|_c1|       _c2|   _c3|
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df=spark.read.option('header','true').csv('/content/test1.csv')
df.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)

# %%
df.head(2)
# Out:
# [Row(Name='Ben', age='31', Experience='10', Salary='30000'),
#  Row(Name='Srikanth', age='30', Experience='8', Salary='25000')]
